# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#  - hello world!

# %%
a = os.getcwd()
print(a)
# Out:
# C:\Users\vinit\Desktop\Python

# %%
wkdir = os.chdir('/Users/vinit/Desktop/Python')
os.listdir('/Users/vinit/Desktop/Python')
# Out:
# ['.ipynb_checkpoints',
#  'ecommerce.csv',
#  'ecommerce.html',
#  'Importing_Data_Python_Cheat_Sheet.pdf',
#  'Untitled.ipynb',
#  'What is a Python Class (AutoRecovered).docx']

# %%
df = pd.read_csv('ecommerce.csv')

# %%
df.head(5)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
correlation_df = df.corr()

# %%
sns.heatmap(correlation_df, vmax = 0.9, linewidths = 0.5, annot= True, square = True,  linecolor = "white" )

# %%
correlation_df.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col4 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col4 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col4 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col1 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col3 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_8d22ec00_bb9c_11e9_a539_34415d1b76ae" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Avg. Session Length</th>        <th class="col_heading level0 col1" >Time on App</th>        <th class="col_heading level0 col2" >Time on Website</th>        <th class="col_heading level0 col3" >Length of Membership</th>        <th class="col_heading level0 col4" >Yearly Amount Spent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aelevel0_row0" class="row_heading level0 row0" >Avg. Session Length</th>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col1" class="data row0 col1" >-0.027826</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col2" class="data row0 col2" >-0.0349869</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col3" class="data row0 col3" >0.0602474</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow0_col4" class="data row0 col4" >0.355088</td>
#             </tr>
#             <tr>
#                         <th id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aelevel0_row1" class="row_heading level0 row1" >Time on App</th>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col0" class="data row1 col0" >-0.027826</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col2" class="data row1 col2" >0.0823883</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col3" class="data row1 col3" >0.0291426</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow1_col4" class="data row1 col4" >0.499328</td>
#             </tr>
#             <tr>
#                         <th id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aelevel0_row2" class="row_heading level0 row2" >Time on Website</th>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col0" class="data row2 col0" >-0.0349869</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col1" class="data row2 col1" >0.0823883</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col3" class="data row2 col3" >-0.0475818</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow2_col4" class="data row2 col4" >-0.00264084</td>
#             </tr>
#             <tr>
#                         <th id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aelevel0_row3" class="row_heading level0 row3" >Length of Membership</th>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col0" class="data row3 col0" >0.0602474</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col1" class="data row3 col1" >0.0291426</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col2" class="data row3 col2" >-0.0475818</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow3_col4" class="data row3 col4" >0.809084</td>
#             </tr>
#             <tr>
#                         <th id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aelevel0_row4" class="row_heading level0 row4" >Yearly Amount Spent</th>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col0" class="data row4 col0" >0.355088</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col1" class="data row4 col1" >0.499328</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col2" class="data row4 col2" >-0.00264084</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col3" class="data row4 col3" >0.809084</td>
#                         <td id="T_8d22ec00_bb9c_11e9_a539_34415d1b76aerow4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, kind= "reg")

# %%
x=sns.PairGrid(df)
x = x.map(plt.scatter)

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
x = df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
y = df[['Yearly Amount Spent']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([[25.40338237, 39.07669655,  0.24709025, 61.96771706]])

# %%
pred_x_test = model.predict(x_test)
prediction = pd.DataFrame(pred_x_test)

# %%
plt.scatter(pred_x_test,y_test)
plt.xlabel('x_test')
plt.ylabel('y_test')
# Out:
# Text(0, 0.5, 'y_test')

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(pred_x_test,y_test))
mse = metrics.mean_squared_error(y_test,pred_x_test)
mae = metrics.median_absolute_error(y_test,pred_x_test)

print('rmse = {}'.format(rmse))
print('mse = {}' .format(mse))
print('mae = {}' .format(mae))
# Out:
# rmse = 10.29305982878902
# mse = 105.94708063903025
# mae = 7.017248389798283

# %%
sns.distplot(pred_x_test, bins = 50, kde=True)
plt.xlabel('Yearly Amount Spent')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
coefficients = pd.DataFrame(data=model.coef_.transpose(), index=x.columns, columns=['Profit Rate'])

# %%
coefficients
# Out:
#                       Profit Rate
# Avg. Session Length     25.403382
# Time on App             39.076697
# Time on Website          0.247090
# Length of Membership    61.967717

# %%
coefficients.plot.bar()
